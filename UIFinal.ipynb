# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QMessageBox

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(696, 353)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.box_mainMenu = QtWidgets.QGroupBox(self.centralwidget)
        self.box_mainMenu.setGeometry(QtCore.QRect(20, 30, 621, 241))
        self.box_mainMenu.setObjectName("box_mainMenu")
        self.label_MainMenu = QtWidgets.QLabel(self.box_mainMenu)
        self.label_MainMenu.setGeometry(QtCore.QRect(10, 30, 621, 61))
        font = QtGui.QFont()
        font.setPointSize(16)
        self.label_MainMenu.setFont(font)
        self.label_MainMenu.setObjectName("label_MainMenu")
        self.button_MMEmployees = QtWidgets.QPushButton(self.box_mainMenu)
        self.button_MMEmployees.setGeometry(QtCore.QRect(400, 200, 121, 31))
        self.button_MMEmployees.setObjectName("button_MMEmployees")
        self.button_MMHumanResource = QtWidgets.QPushButton(self.box_mainMenu)
        self.button_MMHumanResource.setGeometry(QtCore.QRect(100, 200, 111, 31))
        self.button_MMHumanResource.setObjectName("button_MMHumanResource")
        self.box_list = QtWidgets.QGroupBox(self.centralwidget)
        self.box_list.setGeometry(QtCore.QRect(20, 30, 621, 241))
        self.box_list.setObjectName("box_list")
        self.label_LIemployeeCard = QtWidgets.QLabel(self.box_list)
        self.label_LIemployeeCard.setGeometry(QtCore.QRect(30, 40, 201, 16))
        self.label_LIemployeeCard.setObjectName("label_LIemployeeCard")
        self.comboBox_LIemployeeCard = QtWidgets.QComboBox(self.box_list)
        self.comboBox_LIemployeeCard.setGeometry(QtCore.QRect(440, 40, 69, 22))
        self.comboBox_LIemployeeCard.setObjectName("comboBox_LIemployeeCard")
        self.comboBox_LIemployeeCard.addItem("")
        self.comboBox_LIemployeeCard.addItem("")
        self.comboBox_LIemployeeCard.addItem("")
        self.label_LIlaptop = QtWidgets.QLabel(self.box_list)
        self.label_LIlaptop.setGeometry(QtCore.QRect(30, 90, 191, 16))
        self.label_LIlaptop.setObjectName("label_LIlaptop")
        self.comboBox_LIlaptop = QtWidgets.QComboBox(self.box_list)
        self.comboBox_LIlaptop.setGeometry(QtCore.QRect(440, 90, 69, 22))
        self.comboBox_LIlaptop.setObjectName("comboBox_LIlaptop")
        self.comboBox_LIlaptop.addItem("")
        self.comboBox_LIlaptop.addItem("")
        self.comboBox_LIlaptop.addItem("")
        self.label_LIdeclaration = QtWidgets.QLabel(self.box_list)
        self.label_LIdeclaration.setGeometry(QtCore.QRect(30, 140, 221, 16))
        self.label_LIdeclaration.setObjectName("label_LIdeclaration")
        self.comboBox_LIdeclaration = QtWidgets.QComboBox(self.box_list)
        self.comboBox_LIdeclaration.setGeometry(QtCore.QRect(440, 140, 69, 22))
        self.comboBox_LIdeclaration.setObjectName("comboBox_LIdeclaration")
        self.comboBox_LIdeclaration.addItem("")
        self.comboBox_LIdeclaration.addItem("")
        self.comboBox_LIdeclaration.addItem("")
        self.button_LIsubmit = QtWidgets.QPushButton(self.box_list)
        self.button_LIsubmit.setGeometry(QtCore.QRect(430, 200, 101, 31))
        self.button_LIsubmit.setObjectName("button_LIsubmit")
        self.box_onboarding = QtWidgets.QGroupBox(self.centralwidget)
        self.box_onboarding.setGeometry(QtCore.QRect(20, 30, 621, 281))
        self.box_onboarding.setFlat(True)
        self.box_onboarding.setObjectName("box_onboarding")
        self.button_OBsubmit = QtWidgets.QPushButton(self.box_onboarding)
        self.button_OBsubmit.setGeometry(QtCore.QRect(220, 240, 191, 41))
        self.button_OBsubmit.setObjectName("button_OBsubmit")
        self.label_OBfirstName = QtWidgets.QLabel(self.box_onboarding)
        self.label_OBfirstName.setGeometry(QtCore.QRect(30, 30, 81, 21))
        self.label_OBfirstName.setObjectName("label_OBfirstName")
        self.input_OBfirstName = QtWidgets.QLineEdit(self.box_onboarding)
        self.input_OBfirstName.setGeometry(QtCore.QRect(110, 30, 113, 20))
        self.input_OBfirstName.setText("")
        self.input_OBfirstName.setObjectName("input_OBfirstName")
        self.input_OBlastName = QtWidgets.QLineEdit(self.box_onboarding)
        self.input_OBlastName.setGeometry(QtCore.QRect(110, 70, 113, 20))
        self.input_OBlastName.setText("")
        self.input_OBlastName.setObjectName("input_OBlastName")
        self.label_OBlastName = QtWidgets.QLabel(self.box_onboarding)
        self.label_OBlastName.setGeometry(QtCore.QRect(30, 70, 61, 21))
        self.label_OBlastName.setObjectName("label_OBlastName")
        self.input_OBemail = QtWidgets.QLineEdit(self.box_onboarding)
        self.input_OBemail.setGeometry(QtCore.QRect(110, 110, 113, 20))
        self.input_OBemail.setText("")
        self.input_OBemail.setObjectName("input_OBemail")
        self.label_OBemail = QtWidgets.QLabel(self.box_onboarding)
        self.label_OBemail.setGeometry(QtCore.QRect(30, 110, 61, 21))
        self.label_OBemail.setObjectName("label_OBemail")
        self.label_OBaddress = QtWidgets.QLabel(self.box_onboarding)
        self.label_OBaddress.setGeometry(QtCore.QRect(30, 150, 61, 21))
        self.label_OBaddress.setObjectName("label_OBaddress")
        self.input_OBaddress = QtWidgets.QLineEdit(self.box_onboarding)
        self.input_OBaddress.setGeometry(QtCore.QRect(110, 150, 113, 20))
        self.input_OBaddress.setText("")
        self.input_OBaddress.setObjectName("input_OBaddress")
        self.input_OBnumber = QtWidgets.QLineEdit(self.box_onboarding)
        self.input_OBnumber.setGeometry(QtCore.QRect(110, 190, 113, 20))
        self.input_OBnumber.setText("")
        self.input_OBnumber.setObjectName("input_OBnumber")
        self.label_OBnumber = QtWidgets.QLabel(self.box_onboarding)
        self.label_OBnumber.setGeometry(QtCore.QRect(30, 190, 61, 21))
        self.label_OBnumber.setObjectName("label_OBnumber")
        self.box_quiz = QtWidgets.QGroupBox(self.centralwidget)
        self.box_quiz.setGeometry(QtCore.QRect(20, 30, 621, 241))
        self.box_quiz.setObjectName("box_quiz")
        self.comboBox_QZAH = QtWidgets.QComboBox(self.box_quiz)
        self.comboBox_QZAH.setGeometry(QtCore.QRect(440, 40, 69, 22))
        self.comboBox_QZAH.setObjectName("comboBox_QZAH")
        self.comboBox_QZAH.addItem("")
        self.comboBox_QZAH.addItem("")
        self.comboBox_QZAH.addItem("")
        self.comboBox_CW = QtWidgets.QComboBox(self.box_quiz)
        self.comboBox_CW.setGeometry(QtCore.QRect(410, 140, 131, 21))
        self.comboBox_CW.setObjectName("comboBox_CW")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CW.addItem("")
        self.comboBox_CC = QtWidgets.QComboBox(self.box_quiz)
        self.comboBox_CC.setGeometry(QtCore.QRect(440, 90, 69, 22))
        self.comboBox_CC.setObjectName("comboBox_CC")
        self.comboBox_CC.addItem("")
        self.comboBox_CC.addItem("")
        self.comboBox_CC.addItem("")
        self.label_QZAH = QtWidgets.QLabel(self.box_quiz)
        self.label_QZAH.setGeometry(QtCore.QRect(20, 40, 281, 21))
        self.label_QZAH.setObjectName("label_QZAH")
        self.label_QZCW = QtWidgets.QLabel(self.box_quiz)
        self.label_QZCW.setGeometry(QtCore.QRect(20, 90, 301, 16))
        self.label_QZCW.setObjectName("label_QZCW")
        self.label_QZcareer = QtWidgets.QLabel(self.box_quiz)
        self.label_QZcareer.setGeometry(QtCore.QRect(20, 140, 311, 16))
        self.label_QZcareer.setObjectName("label_QZcareer")
        self.button_QZsubmit = QtWidgets.QPushButton(self.box_quiz)
        self.button_QZsubmit.setGeometry(QtCore.QRect(420, 210, 75, 23))
        self.button_QZsubmit.setObjectName("button_QZsubmit")
        self.frame_employee = QtWidgets.QFrame(self.centralwidget)
        self.frame_employee.setGeometry(QtCore.QRect(20, 30, 621, 241))
        self.frame_employee.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_employee.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_employee.setObjectName("frame_employee")
        self.button_onboarding = QtWidgets.QPushButton(self.frame_employee)
        self.button_onboarding.setGeometry(QtCore.QRect(80, 200, 75, 23))
        self.button_onboarding.setObjectName("button_onboarding")
        self.button_quiz = QtWidgets.QPushButton(self.frame_employee)
        self.button_quiz.setGeometry(QtCore.QRect(280, 200, 75, 23))
        self.button_quiz.setObjectName("button_quiz")
        self.button_tdl = QtWidgets.QPushButton(self.frame_employee)
        self.button_tdl.setGeometry(QtCore.QRect(490, 200, 75, 23))
        self.button_tdl.setObjectName("button_tdl")
        self.label_noName = QtWidgets.QLabel(self.frame_employee)
        self.label_noName.setGeometry(QtCore.QRect(0, 30, 671, 51))
        font = QtGui.QFont()
        font.setPointSize(16)
        self.label_noName.setFont(font)
        self.label_noName.setAlignment(QtCore.Qt.AlignCenter)
        self.label_noName.setObjectName("label_noName")
        self.label_name = QtWidgets.QLabel(self.frame_employee)
        self.label_name.setGeometry(QtCore.QRect(0, 22, 671, 71))
        font = QtGui.QFont()
        font.setPointSize(16)
        self.label_name.setFont(font)
        self.label_name.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.label_name.setScaledContents(True)
        self.label_name.setAlignment(QtCore.Qt.AlignCenter)
        self.label_name.setWordWrap(True)
        self.label_name.setObjectName("label_name")
        self.button_onboarding.raise_()
        self.button_quiz.raise_()
        self.button_tdl.raise_()
        self.label_name.raise_()
        self.label_noName.raise_()
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 696, 21))
        self.menubar.setObjectName("menubar")
        self.menuMenu = QtWidgets.QMenu(self.menubar)
        self.menuMenu.setObjectName("menuMenu")
        self.menuEmployee = QtWidgets.QMenu(self.menubar)
        self.menuEmployee.setObjectName("menuEmployee")
        self.menuHuman_Resources = QtWidgets.QMenu(self.menubar)
        self.menuHuman_Resources.setObjectName("menuHuman_Resources")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)
        self.actionHome = QtWidgets.QAction(MainWindow)
        self.actionHome.setObjectName("actionHome")
        self.actionOnboarding = QtWidgets.QAction(MainWindow)
        self.actionOnboarding.setObjectName("actionOnboarding")
        self.actionQuiz = QtWidgets.QAction(MainWindow)
        self.actionQuiz.setObjectName("actionQuiz")
        self.actionTo_do_list = QtWidgets.QAction(MainWindow)
        self.actionTo_do_list.setObjectName("actionTo_do_list")
        self.menuMenu.addAction(self.actionHome)
        self.menuEmployee.addAction(self.actionOnboarding)
        self.menuEmployee.addAction(self.actionQuiz)
        self.menuEmployee.addAction(self.actionTo_do_list)
        self.menubar.addAction(self.menuMenu.menuAction())
        self.menubar.addAction(self.menuEmployee.menuAction())
        self.menubar.addAction(self.menuHuman_Resources.menuAction())

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        
        
        #Button Actions
        self.button_LIsubmit.clicked.connect(self.LIsubmit)
        self.button_MMEmployees.clicked.connect(self.openEmployee)
        self.button_MMHumanResource.clicked.connect(self.incomplete)
        self.button_OBsubmit.clicked.connect(self.OBsubmit)
        self.button_onboarding.clicked.connect(self.openOnboarding)
        self.button_quiz.clicked.connect(self.openQuiz)
        self.button_QZsubmit.clicked.connect(self.QZsubmit)
        self.button_tdl.clicked.connect(self.openToDoList)
        
        
        #Trigger Actions
        self.actionHome.triggered.connect(self.openMainMenu)
        self.actionOnboarding.triggered.connect(self.openOnboarding)
        self.actionQuiz.triggered.connect(self.openQuiz)
        self.actionTo_do_list.triggered.connect(self.openToDoList)
        
        #Start from main menu
        #self.mainMenu()
        self.hideAll()
        self.frame_employee.show()

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.box_mainMenu.setTitle(_translate("MainWindow", "Main menu"))
        self.label_MainMenu.setText(_translate("MainWindow", "Welcome to XYZ Human Resources. How can we help you today?"))
        self.button_MMEmployees.setText(_translate("MainWindow", "Employees"))
        self.button_MMHumanResource.setText(_translate("MainWindow", "Human resources"))
        self.box_list.setTitle(_translate("MainWindow", "To do list/ feedback"))
        self.label_LIemployeeCard.setText(_translate("MainWindow", "Have you collected your employee card?"))
        self.comboBox_LIemployeeCard.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_LIemployeeCard.setItemText(1, _translate("MainWindow", "Yes"))
        self.comboBox_LIemployeeCard.setItemText(2, _translate("MainWindow", "No"))
        self.label_LIlaptop.setText(_translate("MainWindow", "Have you collected your laptop?"))
        self.comboBox_LIlaptop.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_LIlaptop.setItemText(1, _translate("MainWindow", "Yes"))
        self.comboBox_LIlaptop.setItemText(2, _translate("MainWindow", "No"))
        self.label_LIdeclaration.setText(_translate("MainWindow", "Have you collected your signed declaration?"))
        self.comboBox_LIdeclaration.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_LIdeclaration.setItemText(1, _translate("MainWindow", "Yes"))
        self.comboBox_LIdeclaration.setItemText(2, _translate("MainWindow", "No"))
        self.button_LIsubmit.setText(_translate("MainWindow", "Submit"))
        self.box_onboarding.setTitle(_translate("MainWindow", "Onboarding"))
        self.button_OBsubmit.setText(_translate("MainWindow", "Submit"))
        self.label_OBfirstName.setText(_translate("MainWindow", "First name:"))
        self.label_OBlastName.setText(_translate("MainWindow", "Last name:"))
        self.label_OBemail.setText(_translate("MainWindow", "Email:"))
        self.label_OBaddress.setText(_translate("MainWindow", "Address:"))
        self.label_OBnumber.setText(_translate("MainWindow", "HP number:"))
        self.box_quiz.setTitle(_translate("MainWindow", "Quiz"))
        self.comboBox_QZAH.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_QZAH.setItemText(1, _translate("MainWindow", "Yes"))
        self.comboBox_QZAH.setItemText(2, _translate("MainWindow", "No"))
        self.comboBox_CW.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_CW.setItemText(1, _translate("MainWindow", "Professional education"))
        self.comboBox_CW.setItemText(2, _translate("MainWindow", "Team building"))
        self.comboBox_CW.setItemText(3, _translate("MainWindow", "New responsibilities"))
        self.comboBox_CW.setItemText(4, _translate("MainWindow", "Higher salary/bonus"))
        self.comboBox_CW.setItemText(5, _translate("MainWindow", "Promotions"))
        self.comboBox_CW.setItemText(6, _translate("MainWindow", "Public recognition"))
        self.comboBox_CC.setItemText(0, _translate("MainWindow", "<Select>"))
        self.comboBox_CC.setItemText(1, _translate("MainWindow", "Yes"))
        self.comboBox_CC.setItemText(2, _translate("MainWindow", "No"))
        self.label_QZAH.setText(_translate("MainWindow", "Have you signed up for the Anti-Harrassment Workshop?"))
        self.label_QZCW.setText(_translate("MainWindow", "Have you signed up for the Company Culture workshop?"))
        self.label_QZcareer.setText(_translate("MainWindow", "What do you think is important for your professional career?"))
        self.button_QZsubmit.setText(_translate("MainWindow", "Submit"))
        self.button_onboarding.setText(_translate("MainWindow", "Onboarding"))
        self.button_quiz.setText(_translate("MainWindow", "Quiz"))
        self.button_tdl.setText(_translate("MainWindow", "To do list"))
        self.label_noName.setText(_translate("MainWindow", ""))
        self.label_name.setText(_translate("MainWindow", f"Welcome"))
        self.menuMenu.setTitle(_translate("MainWindow", "Menu"))
        self.menuEmployee.setTitle(_translate("MainWindow", "Employee"))
        self.menuHuman_Resources.setTitle(_translate("MainWindow", "Human Resources"))
        self.actionHome.setText(_translate("MainWindow", "Main Menu"))
        self.actionOnboarding.setText(_translate("MainWindow", "Onboarding"))
        self.actionQuiz.setText(_translate("MainWindow", "Quiz"))
        self.actionTo_do_list.setText(_translate("MainWindow", "To-do list"))
   

    #Functions - moving to pages:
        
    def hideAll(self):
        self.box_mainMenu.hide()
        self.box_list.hide()
        self.box_onboarding.hide()
        self.box_quiz.hide()
        self.frame_employee.hide()
        
    def openMainMenu(self):
        self.hideAll()
        self.box_mainMenu.show()
        
    def openEmployee(self):
        self.hideAll()
        self.frame_employee.show()
        self.label_noName.hide()
    
    def openToDoList(self):
        self.hideAll()
        self.box_list.show()
    
    def openOnboarding(self):
        self.hideAll()
        self.box_onboarding.show()
        
    def openQuiz(self):
        self.hideAll()
        self.box_quiz.show()
        
    def incomplete(self):
        msg = QMessageBox()
        msg.setWindowTitle("Warning")
        msg.setText("Site work in progress")
        msg.setIcon(QMessageBox.Information)
        msg.setStandardButtons(QMessageBox.Ok)
        
        x= msg.exec_()
    
    
    #Functions - page specific
    def OBsubmit(self):
        #Input
        globals
        firstName = self.input_OBfirstName.text()
        lastName = self.input_OBlastName.text()
        email = self.input_OBemail.text()
        address = self.input_OBaddress.text()
        number = self.input_OBnumber.text()
        
        if firstName == '' or lastName == '' or email == '' or address == '' or number == '':
            self.inputWarning()
        
        else:
            self.submitAlert()
            self.openEmployee()
        
    def QZsubmit(self):
        
        if self.comboBox_QZAH.currentIndex() == 0 or self.comboBox_CC.currentIndex() == 0 or self.comboBox_CW.currentIndex() == 0:
            self.inputWarning()
            
        else:
            antiHarassment = self.comboBox_QZAH.currentText()
            companyCulture = self.comboBox_CC.currentText()
            professionalCareer = self.comboBox_CW.currentText()
            self.submitAlert()
            self.openEmployee()
        
    def LIsubmit(self):
        
        if self.comboBox_LIdeclaration.currentIndex() == 0 or self.comboBox_LIemployeeCard.currentIndex() == 0 or self.comboBox_LIlaptop.currentIndex() == 0:
            self.inputWarning()
            
        
        else:
            declaration = self.comboBox_LIdeclaration.currentText()
            laptop = self.comboBox_LIlaptop
            employeeCard = self.comboBox_LIemployeeCard.currentText()
            self.submitAlert()
            self.openEmployee()
        
    
    def submitAlert(self):
        msg = QMessageBox()
        msg.setWindowTitle("Submit")
        msg.setText("Submitted")
        msg.setIcon(QMessageBox.Information)
        msg.setStandardButtons(QMessageBox.Ok)
        
        x= msg.exec_()
    
    def inputWarning(self):
        msg = QMessageBox()
        msg.setWindowTitle("Warning")
        msg.setText("Please fill out the form")
        msg.setIcon(QMessageBox.Information)
        msg.setStandardButtons(QMessageBox.Ok)
        
        x= msg.exec_()
        
        

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
